# %%
import pandas as pd
import argparse
import json

from PIL import Image
from bs4 import BeautifulSoup
from collections import Counter
from textractor import Textractor
from pdf2image import convert_from_path
from unstructured.partition.pdf import partition_pdf
from textractor.data.constants import TextractFeatures

# %%
extractor = Textractor(profile_name="default")

# %%
def extract_page_as_image(pdf_path, page_number, output_image_path, crop_coords=None):

    images = convert_from_path(pdf_path, first_page=page_number, last_page=page_number)
    
    if crop_coords:
        left = min(point[0] for point in crop_coords)
        top = min(point[1] for point in crop_coords)
        right = max(point[0] for point in crop_coords)
        bottom = max(point[1] for point in crop_coords)
        images[0] = images[0].crop((left, top, right, bottom))
    
    images[0].save(output_image_path, 'PNG')
    
def parse_command_line_arguments():
    parser = argparse.ArgumentParser()

    parser.add_argument('--document_path', type=str, help='The path to the input PDF document.')
    parser.add_argument('--save_path', type=str, help='The path where to print the parsed json document.')

    return parser.parse_args()

def prepare_counter(elements):

    titles_text = [el.text for el in elements if el.category == "Title"]
    text_text = [el.text for el in elements if el.category == "Text"]
    narrtext_text = [el.text for el in elements if el.category == "NarrativeText"]

    all_text = titles_text + narrtext_text + text_text
    all_counter = Counter(all_text)

    return all_counter

def create_parsed_dictionary(elements, all_counter):
    parsed_doc = {'page_1': ''}
    curr_page = 'page_1'
    page_number = 1

    for el in elements:

        if el.category == 'PageBreak':
            page_number += 1
            curr_page = f"page_{page_number}"
            parsed_doc[curr_page] = ''

        elif el.category == 'ListItem':
            if all_counter[el.text] < 10 and all_counter[el.text] != 0:
                parsed_doc[curr_page] += el.text
                parsed_doc[curr_page] += '\n'
        
        elif el.category == 'NarrativeText':
            if all_counter[el.text] < 10 and all_counter[el.text] != 0:
                parsed_doc[curr_page] += el.text
                parsed_doc[curr_page] += ' '

        elif el.category == 'Table':
            parsed_doc[curr_page] += '\n'
            parsed_doc[curr_page] += el.metadata.text_as_html
            parsed_doc[curr_page] += '\n'

        elif el.category == 'Text':
            if all_counter[el.text] < 10 and all_counter[el.text] != 0:
                parsed_doc[curr_page] += el.text
                parsed_doc[curr_page] += ' '

        elif el.category == 'Title':
            if page_number == 1:
                parsed_doc[curr_page] += el.text
                parsed_doc[curr_page] += '\n'
            elif all_counter[el.text] < 10 and all_counter[el.text] != 0:
                parsed_doc[curr_page] += el.text
                parsed_doc[curr_page] += '\n'
        
    parsed_doc = {k:v for k,v in parsed_doc.items() if v}   

    return parsed_doc


def save_parsed_document(parsed_doc, save_path):
    with open(save_path, 'w') as f:
        json.dump(parsed_doc, f)

# %%
filename='valvole-di-controllo-rotative-vee-ball-modello-v150-v200-e-v300-da-1-a-12-in-fisher-vee-ball-v150-v200-v300-rotary-control-valves-nps-1-through-12-italian-it-134892.pdf'

elements = partition_pdf(filename=filename, infer_table_structure=True, include_page_breaks=True, languages=['ita', 'eng'])
all_counter = prepare_counter(elements=elements)
# Out:
# Some weights of the model checkpoint at microsoft/table-transformer-structure-recognition were not used when initializing TableTransformerForObjectDetection: ['model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer3.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked']
# - This IS expected if you are initializing TableTransformerForObjectDetection from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TableTransformerForObjectDetection from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
parsed_doc = {'page_1': ''}
curr_page = 'page_1'
page_number = 1
tables = []
n=0

for el in elements:

    if el.category == 'PageBreak':
        page_number += 1
        curr_page = f"page_{page_number}"
        parsed_doc[curr_page] = ''

    elif el.category == 'ListItem':
        if all_counter[el.text] < 10 and all_counter[el.text] != 0:
            parsed_doc[curr_page] += el.text
            parsed_doc[curr_page] += '\n'
    
    elif el.category == 'NarrativeText':
        if all_counter[el.text] < 10 and all_counter[el.text] != 0:
            parsed_doc[curr_page] += el.text
            parsed_doc[curr_page] += ' '

    elif el.category == 'Table':
        parsed_doc[curr_page] += '\n'
        pdf_path = filename
        page_number = el.metadata.page_number 
        coords = el.metadata.coordinates.points 
        output_image_path = f'output_{n}.png'
        extract_page_as_image(pdf_path, page_number, output_image_path, coords)
        document = extractor.analyze_document(file_source=f'output_{n}.png',features=[TextractFeatures.TABLES])
        if len(document.tables) > 0:
            for k in range(len(document.tables)):
                #table_html = document.tables[0].to_pandas().to_html()
                table_format = document.tables[k].to_pandas().to_markdown()
                tables.append(document.tables[k].to_pandas())
                parsed_doc[curr_page] += table_format
                parsed_doc[curr_page] += '\n'
                n+=1
        else:
            pass
        

    elif el.category == 'Text':
        if all_counter[el.text] < 10 and all_counter[el.text] != 0:
            parsed_doc[curr_page] += el.text
            parsed_doc[curr_page] += ' '

    elif el.category == 'Title':

        if page_number == 1:
            parsed_doc[curr_page] += el.text
            parsed_doc[curr_page] += '\n'
        elif all_counter[el.text] < 10 and all_counter[el.text] != 0:
            parsed_doc[curr_page] += el.text
            parsed_doc[curr_page] += '\n'

parsed_doc = {k:v for k,v in parsed_doc.items() if v}

# %%
for index, el in enumerate(elements):
    if el.category == 'Table':
        print(f"Element at position {index} is a Table")
# Out:
# Element at position 6 is a Table
# Element at position 55 is a Table
# Element at position 73 is a Table
# Element at position 140 is a Table
# Element at position 283 is a Table
# Element at position 289 is a Table
# Element at position 290 is a Table
# Element at position 317 is a Table
# Element at position 397 is a Table
# Element at position 455 is a Table
# Element at position 457 is a Table
# Element at position 527 is a Table
# Element at position 530 is a Table
# Element at position 749 is a Table
# Element at position 767 is a Table
# Element at position 786 is a Table
# Element at position 790 is a Table
# Element at position 802 is a Table
# Element at position 924 is a Table
# Element at position 979 is a Table
# Element at position 981 is a Table
# Element at position 1044 is a Table
# Element at position 1045 is a Table

# %%
len(tables)
# Out:
# 26

# %%
html_content = elements[6].metadata.text_as_html
soup = BeautifulSoup(html_content, 'html.parser')
table = soup.find('table')
df = pd.read_html(str(table))[0]

df
# Out:
#                                  Introduzione .......  \
# 0                     Scopo del manuale..............
# 1                                         Descrizione
# 2                                      Specifiche ...
# 3                                   Servizi educativi
# 4                                  Installazione 0...
# 5                         Manutenzione ..............
# 6                                  Manutenzione della
# 7                                  Sostituzione della
# 8                 Smontaggio Montaggio Lubrificazione
# 9                         rinforzata Manutenzione del
# 10  Sostituzione della Valvole DN 25-50(da1a2pollici)
# 11                          Installazione di Cavitrol
# 12                           Montaggio dell'attuatore
# 13      Scelta della posizione Scelta della posizione
# 14          chiusura ... 2.2 Ordinazione dei pezzi 39
# 15                                    .......... wee.
# 16               Kit dei pezzi... eee eee eee 41 cece
# 17                            Elenco pezzi ........ A
#
#                                    Unnamed: 1  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                        2...
# 5                                         NaN
# 6                                         NaN
# 7                                      tenuta
# 8                                       della
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                      di di
# 14  chiusura ... 2.2 Ordinazione dei pezzi 39
# 15                            .......... wee.
# 16       Kit dei pezzi... eee eee eee 41 cece
# 17                                        NaN
#
#                                            6.  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                  ..........
# 4                                         NaN
# 5                                         NaN
# 6                                     baderna
# 7                                         NaN
# 8                 ................ ..........
# 9                          00.2... cuscinetto
# 10                                     chiave
# 11                                        Hex
# 12                                        NaN
# 13                                  montaggio
# 14  chiusura ... 2.2 Ordinazione dei pezzi 39
# 15                            .......... wee.
# 16       Kit dei pezzi... eee eee eee 41 cece
# 17                                      00...
#
#                                    Unnamed: 3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                        cece
# 5                                         NaN
# 6                                         NaN
# 7                                       della
# 8                                      tenuta
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                 ....................000004
# 13                                        NaN
# 14  chiusura ... 2.2 Ordinazione dei pezzi 39
# 15                            .......... wee.
# 16       Kit dei pezzi... eee eee eee 41 cece
# 17                                        NaN
#
#                                    Unnamed: 4  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                        0...
# 4                                         NaN
# 5                                         NaN
# 6                                      ......
# 7                                       sfera
# 8                                  cece della
# 9                                   eee della
# 10                                     conica
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14  chiusura ... 2.2 Ordinazione dei pezzi 39
# 15                            .......... wee.
# 16       Kit dei pezzi... eee eee eee 41 cece
# 17                                        NaN
#
#                                    Unnamed: 5  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                           c
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                           .
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14  chiusura ... 2.2 Ordinazione dei pezzi 39
# 15                            .......... wee.
# 16       Kit dei pezzi... eee eee eee 41 cece
# 17                                        eee
#
#                                    Unnamed: 6  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14  chiusura ... 2.2 Ordinazione dei pezzi 39
# 15                            .......... wee.
# 16       Kit dei pezzi... eee eee eee 41 cece
# 17                                        NaN
#
#                                           cee  \
# 0                                       0.0.0
# 1                                         NaN
# 2                                         NaN
# 3                                         eee
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                  cece sfera
# 9                                       sfera
# 10                  saldata .................
# 11                                        NaN
# 12                                        NaN
# 13                                       ....
# 14  chiusura ... 2.2 Ordinazione dei pezzi 39
# 15                            .......... wee.
# 16       Kit dei pezzi... eee eee eee 41 cece
# 17                                        eee
#
#                                          cece  \
# 0                                       e eee
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14  chiusura ... 2.2 Ordinazione dei pezzi 39
# 15                            .......... wee.
# 16       Kit dei pezzi... eee eee eee 41 cece
# 17                                        eee
#
#                                    Unnamed: 9  \
# 0                                         eee
# 1                                         NaN
# 2                                         NaN
# 3                                         eee
# 4                                         eee
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         eee
# 9                                         eee
# 10                                  .........
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14  chiusura ... 2.2 Ordinazione dei pezzi 39
# 15                            .......... wee.
# 16       Kit dei pezzi... eee eee eee 41 cece
# 17                                        NaN
#
#                                           eee  \
# 0                                          ee
# 1                                         NaN
# 2                                         NaN
# 3                                         eee
# 4                                         NaN
# 5                                         wee
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14  chiusura ... 2.2 Ordinazione dei pezzi 39
# 15                            .......... wee.
# 16       Kit dei pezzi... eee eee eee 41 cece
# 17                                       wee.
#
#                                         eee.1  \
# 0                                         eee
# 1                                         NaN
# 2                                         NaN
# 3                                         eee
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                       . eee
# 9                                         eee
# 10                                        NaN
# 11                                          .
# 12                                        NaN
# 13                                          .
# 14  chiusura ... 2.2 Ordinazione dei pezzi 39
# 15                            .......... wee.
# 16       Kit dei pezzi... eee eee eee 41 cece
# 17                                        NaN
#
#                                             1
# 0                                           1
# 1                                           2
# 2                                           2
# 3                                           2
# 4                                       eee 3
# 5                                           8
# 6                                        ...8
# 7                                          11
# 8                                       11 14
# 9                                         NaN
# 10                                      24 25
# 11                                         32
# 12                                         33
# 13                                      33 33
# 14  chiusura ... 2.2 Ordinazione dei pezzi 39
# 15                            .......... wee.
# 16       Kit dei pezzi... eee eee eee 41 cece
# 17                                         43

# %%
tables[0]
# Out:
#                                                     0        1
# 0                                     Introduzione 1
# 1                                Scopo del manuale 1
# 2                                      Descrizione 2
# 3                                       Specifiche 2
# 4                                  Servizi educativi        2
# 5                                      Installazione        3
# 6                                       Manutenzione        8
# 7                       Manutenzione della baderna 8
# 8       Sostituzione della tenuta della sfera 11 [ ]
# 9                                  Smontaggio 11 [ ]
# 10                                         Montaggio   14 [X]
# 11  Lubrificazione della tenuta della sfera rinfor...
# 12         Manutenzione del cuscinetto e della sfera       20
# 13           Valvole DN 80 - 300 (da 3 a 12 pollici)       20
# 14          Sostituzione della chiave conica saldata       24
# 15             Valvole DN 25 - 50 (da 1 a 2 pollici)       25
# 16                     Installazione di Cavitrol Hex       32
# 17                          Montaggio dell'attuatore       33
# 18       Valvole da 3 a 12 pollici senza attenuatore       33
# 19               Scelta della posizione di montaggio       33
# 20                Scelta della posizione di chiusura       33
# 21                             Ordinazione dei pezzi       39
# 22                                     Kit dei pezzi       41
# 23                                      Elenco pezzi       43
# 24    Appendice A Istruzioni per valvole non serie B       44

# %%
html_content = elements[55].metadata.text_as_html

soup = BeautifulSoup(html_content, 'html.parser')
table = soup.find('table')
df = pd.read_html(str(table))[0]

df
# Out:
#                DESIGN DELLA VALVOLA  \
#    MATERIALE DEL CORPO VALVOLA Wwcc
# 0                             Vv150
# 1                             Vv150
# 2                             Vv150
# 3                             Vv150
# 4                             Vv150
# 5                             Vv150
# 6                             Vv150
# 7                             Vv150
# 8                             Vv150
# 9                             Vv150
# 10                            Vv150
# 11                            Vv150
# 12                            Vv150
# 13                            Vv150
# 14                            Vv150
# 15                            Vv150
# 16                          v200(4)
# 17                          v200(4)
# 18                          v200(4)
# 19                          v200(4)
# 20                          v200(4)
# 21                          v200(4)
# 22                          v200(4)
# 23                          v200(4)
# 24                          v200(4)
# 25                             v300
# 26                             v300
# 27                             v300
# 28                             v300
# 29                             v300
# 30                             v300
# 31                             v300
# 32                             v300
# 33                             v300
# 34                             v300
# 35                             v300
# 36                             v300
# 37                             v300
# 38                             v300
# 39                             v300
# 40                             v300
# 41                             v300
# 42                             v300
# 43                             v300
#
#                      MATERIALE DEL CORPO VALVOLA Wwcc  \
#                                    Unnamed: 1_level_1
# 0   1, 1-1/2, 2, 3, 4, 6, 8, 10, 12, 14, 16, 20, 2...
# 1                                   Wcc | 1.0619(1) .
# 2                                   Wcc | 1.0619(1) .
# 3                                                 tcc
# 4                                                 tcc
# 5                                                 tcc
# 6                                             CF3M(4)
# 7                                       CF3M/1.4409()
# 8                                       CF3M/1.4409()
# 9              CW2M M35-2 CD3MN\3) CD3MWCuNG) CK3MCuN
# 10             CW2M M35-2 CD3MN\3) CD3MWCuNG) CK3MCuN
# 11             CW2M M35-2 CD3MN\3) CD3MWCuNG) CK3MCuN
# 12             CW2M M35-2 CD3MN\3) CD3MWCuNG) CK3MCuN
# 13             CW2M M35-2 CD3MN\3) CD3MWCuNG) CK3MCuN
# 14             CW2M M35-2 CD3MN\3) CD3MWCuNG) CK3MCuN
# 15           WCC, LCC, CG8M o CF3M(2) WCC, LCC 0 CG8M
# 16           WCC, LCC, CG8M o CF3M(2) WCC, LCC 0 CG8M
# 17           WCC, LCC, CG8M o CF3M(2) WCC, LCC 0 CG8M
# 18           WCC, LCC, CG8M o CF3M(2) WCC, LCC 0 CG8M
# 19           WCC, LCC, CG8M o CF3M(2) WCC, LCC 0 CG8M
# 20           WCC, LCC, CG8M o CF3M(2) WCC, LCC 0 CG8M
# 21           WCC, LCC, CG8M o CF3M(2) WCC, LCC 0 CG8M
# 22           WCC, LCC, CG8M o CF3M(2) WCC, LCC 0 CG8M
# 23                              CW2M, M35-2 0 CK3MCUN
# 24                                            CK3MCuN
# 25                                               Wwcc
# 26                                                NaN
# 27                                     WCC / 1.0619()
# 28                                     WCC / 1.0619()
# 29                                     WCC / 1.0619()
# 30                                     WCC / 1.0619()
# 31                                        tec CF3M(4)
# 32                                        tec CF3M(4)
# 33                                        tec CF3M(4)
# 34                                        tec CF3M(4)
# 35                                     CF3M/1.4409(1)
# 36                                     CF3M/1.4409(1)
# 37                                     CF3M/1.4409(1)
# 38                                               CG8M
# 39                                               CW2M
# 40                                              M35-2
# 41                                           CD3MN\3)
# 42                                         CD3MWCuNG)
# 43                                            CK3MCuN
#
#                                           POLLICI/ DN  \
#                                    Unnamed: 2_level_1
# 0                                               CL150
# 1                                     DN 80, 100, 150
# 2                                    DN 200, 250, 300
# 3             1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 4                                     DN 80, 100, 150
# 5                                    DN 200, 250, 300
# 6             1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 7                                     DN 80, 100, 150
# 8                                    DN 200, 250, 300
# 9             1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 10                    1, 1-1/2, 2, 3, 4, 6, 8 pollici
# 11                                                  —
# 12            1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 13            1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 14            1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 15                                1, 1-1/2, 2 pollici
# 16                                                NaN
# 17                                        3,4 pollici
# 18                                           6 8 poll
# 19                                                NaN
# 20                                         10 pollici
# 21                                                NaN
# 22                               2,3, 4, 6 08 pollici
# 23                    1, 1-1/2, 2, 3, 4, 6, 8 pollici
# 24                                         10 pollici
# 25  1, 1-1/2, 2, 3, 4, 6, 8, 10, 12, 14, 16, 20 po...
# 26                                      DN 25, 40, 50
# 27                                    DN 80, 100, 150
# 28                                             DN 300
# 29                                          200, 250,
# 30            1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 31                                      DN 25, 40, 50
# 32                                    DN 80, 100, 150
# 33                                   DN 200, 250, 300
# 34            1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 35                                      DN 25, 40, 50
# 36                                    DN 80, 100, 150
# 37                                   DN 200, 250, 300
# 38  1, 1-1/2, 2, 3, 4, 6, 8, 10, 12, 14, 16, 20 po...
# 39                    1, 1-1/2, 2, 3, 4, 6, 8 pollici
# 40                    1, 1-1/2, 2, 3, 4, 6, 8 pollici
# 41          — 1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 42            1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 43            1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
#
#                                ASME | PN
#                       Unnamed: 3_level_1
# 0                                    NaN
# 1                               PN 10-16
# 2                             PN 100PN16
# 3                                  CL150
# 4                               PN 10-16
# 5   PN 100PN16 CL150 PN 10-16 PN 100PN16
# 6   PN 100PN16 CL150 PN 10-16 PN 100PN16
# 7   PN 100PN16 CL150 PN 10-16 PN 100PN16
# 8   PN 100PN16 CL150 PN 10-16 PN 100PN16
# 9                                  CL150
# 10                                 CL150
# 11                                 CL150
# 12                                 CL150
# 13                                 CL150
# 14                                 CL150
# 15           CL150/300/600 senza flangia
# 16                          CL150e senza
# 17                               Sengiso
# 18                     €1150/300 e CL600
# 19                         senza flangia
# 20                   CL150 senza flangia
# 21                                   NaN
# 22                                 CL600
# 23           CL150/300/600 senza flangia
# 24                   CL150 senza flangia
# 25                                 CL300
# 26                              PN 10-40
# 27                              PN 25-40
# 28                           PN 250 PN40
# 29                                   NaN
# 30                                 CL300
# 31                              PN 10-40
# 32                              PN 25-40
# 33                           PN 250 PN40
# 34                                 CL300
# 35                              PN 10-40
# 36                              PN 25-40
# 37                           PN 250 PN40
# 38                                 CL300
# 39                                 CL300
# 40                                 CL300
# 41                                 CL300
# 42                                 CL300
# 43                                 CL300

# %%
tables[1]
# Out:
#                         0                             1  \
# 0   DESIGN DELLA VALVOLA   MATERIALE DEL CORPO VALVOLA
# 1
# 2                   V150                           WCC
# 3                                        WCC /1.0619()
# 4
# 5                                                  LCC
# 6
# 7
# 8                                                CF3M2
# 9                                       CF3M/1.4409(1)
# 10
# 11                                                CG8M
# 12                                                CW2M
# 13                                               M35-2
# 14                                              CD3MN³
# 15                                         CD3MWCuN(3)
# 16                                             CK3MCuN
# 17               V200(4)        WCC, LCC, CG8M o CF3M2
# 18
# 19
# 20
# 21                                     WCC, LCC o CG8M
# 22                               CW2M, M35-2 o CK3MCuN
# 23                                             CK3MCuN
# 24                  V300                           WCC
# 25                                          WCC/1.0619
# 26
# 27
# 28                                                 LCC
# 29
# 30
# 31
# 32                                               CF3M2
# 33                                        CF3M/1.4409¹
# 34
# 35
# 36                                                CG8M
# 37                                                CW2M
# 38                                               M35-2
# 39                                              CD3MN³
# 40                                         CD3MWCuN(3)
# 41                                             CK3MCuN
#
#                                                     2  \
# 0                                         DIMENSIONE
# 1                                       POLLICI I DN
# 2   3, 4, 6, 8, 10, 12, 14, 16, 20, 24x20 pollici(5)
# 3                                    DN 80, 100, 150
# 4                                     DN 200,250,300
# 5            1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 6                                    DN 80, 100, 150
# 7                                   DN 200, 250, 300
# 8            1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 9                                    DN 80, 100, 150
# 10                                    DN 200,250,300
# 11  1, 1-1/2, 2, 3. 4, 6, 8, 10, 12, 14, 16, 20, 2...
# 12           1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 13                        1,1-1/2,2,3,4,6, 8 pollici
# 14                   ,1-1/2,2,3,4,6,8,10, 12 pollici
# 15           1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 16           1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 17                                 1,1-1/2,2 pollici
# 18                                        3, pollici
# 19                                      6, 8 pollici
# 20                                        10 pollici
# 21                            2, 3, 4, 6 o 8 pollici
# 22                   1, 1-1/2, 2, 3, 4, 6, 8 pollici
# 23                                        10 pollici
# 24     1-1/2, 3, 4, 6, 8, 10, 12, 14, 16, 20 pollici
# 25                                     DN 25, 40, 50
# 26                                    DN 80,100, 150
# 27                                    DN 200,250,300
# 28              1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 29                                     DN 25, 40, 50
# 30                                   DN 80, 100, 150
# 31                                  DN 200, 250, 300
# 32           1, 1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 33                                     DN 25, 40, 50
# 34                                   DN 80, 100, 150
# 35                                  DN 200, 250, 300
# 36  1-1/2, 2, 3, 4, 6, 8, 10, 12, 14, 16, 20 pollici
# 37                   1, 1-1/2, 2, 3, 4, 6, 8 pollici
# 38                         1,1-1/2,2,3,4,6,8 pollici
# 39              1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 40              1-1/2, 2, 3, 4, 6, 8, 10, 12 pollici
# 41                     2, 3, 4, 6, 8, 10, 12 pollici
#
#                                    3
# 0                   VALORI NOMINALI
# 1                         ASME / PN
# 2                             CL150
# 3                          PN 10-16
# 4                     PN 10 o PN 16
# 5                             CL150
# 6                          PN 10-16
# 7                     PN 10 o PN 16
# 8                           CL L150
# 9                          PN 10-16
# 10                    PN 10 o PN 16
# 11                            CL150
# 12
# 13
# 14
# 15
# 16
# 17      CL150/300/600 senza flangia
# 18  CL150 e CL300/600 senza flangia
# 19  CL150/300 e CL600 senza flangia
# 20              CL150 senza flangia
# 21                            CL600
# 22      CL150/300/600 senza flangia
# 23              CL150 senza flangia
# 24                            CL300
# 25                         PN 10-40
# 26                         PN 25-40
# 27                    PN 25 o PN 40
# 28                            CL300
# 29                         PN 10-40
# 30                         PN 25-40
# 31                    PN 25 o PN 40
# 32                            CL300
# 33                         PN 10-40
# 34                         PN 25-40
# 35                    PN 25 o PN 40
# 36                            CL300
# 37
# 38
# 39
# 40
# 41

# %%
html_content = elements[73].metadata.text_as_html
soup = BeautifulSoup(html_content, 'html.parser')
table = soup.find('table')
df = pd.read_html(str(table))[0]

df
# Out:
#   DIMENSIONE DELLA VALVOLA          \
#   DIMENSIONE DELLA VALVOLA
#                         DN Pollici
# 0                  250 300   10 12
#
#                                            eso             \
#   Misura da faccia a faccia ANSI/ISA S75.08.02
#                                             mm        in.
# 0                                      133 140  5.25 5.50
#
#                                                           \
#   Misura da faccia a faccia ASME B16.10 corta
#                                            mm        in.
# 0                                     165 159  6.50 6.25
#
#   v200(1) Misura da faccia a faccia ANSI/ISA S75.08.02       \
#   v200(1) Misura da faccia a faccia ANSI/ISA S75.08.02
#                                                     mm  in.
# 0                                                NaN    cee
#
#   v300() Misura da faccia a faccia ANSI/ISA S75.08.02
#   v300() Misura da faccia a faccia ANSI/ISA S75.08.02
#                                                    mm        in.
# 0                                            171 184   6.75 7.25

# %%
tables[2]
# Out:
#                             0         1  \
# 0   DIMENSIONE DELLA VALVOLA
# 1
# 2                         DN   Pollici
# 3                         25         1
# 4                         40     1-1/2
# 5                         50         2
# 6                         80         3
# 7                    100 150         4
# 8                        200         6
# 9                        250      8 10
# 10                       300        12
# 11
#
#                                                 2  \
# 0                                        V150(2)
# 1   Misura da faccia a faccia ANSI/ISA S75.08.02
# 2                                             mm
# 3                                             70
# 4                                             83
# 5                                             95
# 6                                             95
# 7                                            108
# 8                                            114
# 9                                        121 133
# 10                                           140
# 11
#
#                                                 3  \
# 0
# 1
# 2                                            in.
# 3   2.75 3.25 3.75 3.75 4.25 4.50 4.75 5.25 5.50
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11
#
#                                                4  \
# 0
# 1   Misura da faccia a faccia ASME B16.10 corta
# 2                                            mm
# 3            95 127 146 133 146 152 171 165 159
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11
#
#                                                 5  \
# 0
# 1
# 2                                            in.
# 3   3.75 5.00 5.75 5.25 5.75 6.00 6.75 6.50 6.25
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11
#
#                                                 6                          7  \
# 0                                        V200(¹)
# 1   Misura da faccia a faccia ANSI/ISA S75.08.02
# 2                                             mm                        in.
# 3                            121 140 165 197 216   4.75 5.50 6.50 7.75 8.50
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11
#
#                                                 8  \
# 0                                        V300(2)
# 1   Misura da faccia a faccia ANSI/ISA S75.08.02
# 2                                             mm
# 3              89 102 95 121 127 140 152 171 184
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11
#
#                                                 9
# 0
# 1
# 2                                            in.
# 3   3.50 4.00 3.75 4.75 5.00 5.50 6.00 6.75 7.25
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 11

# %%
html_content = elements[140].metadata.text_as_html
soup = BeautifulSoup(html_content, 'html.parser')
table = soup.find('table')
df = pd.read_html(str(table))[0]

df
# Out:
#   DIMENSIONE VALVOLA 200, POLLICI                              A  \
#   DIMENSIONE VALVOLA 200, POLLICI Standard ANSI/ISA $75.08.02(1)
# 0                              mm                             mm
# 1                       1 1-1/2 2                    102 114 124
# 2                           3 4 6                    165 194 229
# 3                            8 10                        243 297
# 4                             in.                            in.
# 5                       1 1-1/2 2                 4.00 4.50 4.88
# 6                           3 4 6                 6.50 7.62 9.00
# 7                            8 10                     9.56 11.69
#
#                                                       B  \
#   L150 ASME B16.10(2) corta (opzionale)               B
# 0                                    mm              mm
# 1                           127 165 178        58 64 57
# 2                           203 229 267       87 92 119
# 3                               292 330         119 151
# 4                                   in.             in.
# 5                        5.00 6.50 7.00  2.29 2.50 2.25
# 6                       8.00 9.00 10.50  3.44 3.62 4.69
# 7                           11.50 13.00       4.69 5.94
#
#                                      M                                         \
#   Standard CL150 ANSI/ISA $75.08.02(1) CL150 ASME B16.10(2) corta (opzionale)
# 0                                   mm                                     mm
# 1                           176 189 21                            202 240 268
# 2                          254 286 343                            286 321 381
# 3                              343 419                                394 451
# 4                                  in.                                    in.
# 5                       6.94 7.44 8.31                        7.94 9.44 10.56
# 6                    10.00 11.25 13.50                      11.25 12.62 15.00
# 7                          13.50 16.50                            15.50 17.75
#
#
#                CL300              cL600
# 0                 mm                 mm
# 1        202 224 237        202 224 237
# 2        279 305 362        286 343 423
# 3              387 _              426 a
# 4                in.                in.
# 5     7.94 8.81 9.31     7.94 8.81 9.31
# 6  11.00 12.00 14.25  11.25 13.50 16.25
# 7            15.25 a           16.75 os

# %%
tables[3]
# Out:
#                                     0                                1  \
# 0   DIMENSIONE VALVOLA V200, POLLICI                       DIMENSIONE
# 1                                                                   A
# 2                                      Standard ANSI/ISA S75.08.02(1)
# 3                                 mm
# 4                          1 1-1/2 2                      102 114 124
# 5                              3 4 6                      165 194 229
# 6                               8 10                          243 297
# 7                                in.
# 8                          1 1-1/2 2                   4.00 4.50 4.88
# 9                              3 4 6                   6.50 7.62 9.00
# 10                              8 10                       9.56 11.69
#
#                                         2                3  \
# 0
# 1                                                       B
# 2   CL150 ASME B16.10² corta (opzionale)
# 3
# 4                            127 165 178         58 64 57
# 5                            203 229 267        87 92 119
# 6                                292 330          119 151
# 7
# 8                         5.00 6.50 7.00   2.29 2.50 2.25
# 9                        8.00 9.00 10.50   3.44 3.62 4.69
# 10                           11.50 13.00        4.69 5.94
#
#                                       4  \
# 0
# 1                                    M
# 2   Standard CL150 ANSI/ISA S75.08.02¹
# 3
# 4                          176 189 211
# 5                          254 286 343
# 6                              343 419
# 7
# 8                       6.94 7.44 8.31
# 9                    10.00 11.25 13.50
# 10                         13.50 16.50
#
#                                         5                   6  \
# 0
# 1
# 2   CL150 ASME B16.10² corta (opzionale)               CL300
# 3
# 4                            202 240 268         202 224 237
# 5                            286 321 381         279 305 362
# 6                                394 451                 387
# 7
# 8                        7.94 9.44 10.56      7.94 8.81 9.31
# 9                      11.25 12.62 15.00   11.00 12.00 14.25
# 10                           15.50 17.75               15.25
#
#                      7
# 0
# 1
# 2               CL600
# 3
# 4         202 224 237
# 5         286 343 423
# 6                 426
# 7
# 8      7.94 8.81 9.31
# 9   11.25 13.50 16.25
# 10              16.75
